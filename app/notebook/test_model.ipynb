# %%
from langgraph.graph import StateGraph

# %%
data={
    "firstName":"Salar",
    "lastName":"Ahmed",
    "achievements":"I work on langgraph"
    
}

# %%
import os
print(os.getcwd())
# Out:
# d:\Projects\Cv Analyzer\app\notebook

# %%
import sys
import os

# Adds the parent directory (Cv Analyzer) to the search path
sys.path.append(os.path.abspath(".."))

from agents.cv_builder import clean_data

# %%
clean_data({"input":data})
# Out:
# {'input': {'firstName': 'Salar',
#   'lastName': 'Ahmed',
#   'achievements': 'I work on langgraph'}}

# %%
from agents.cv_builder import improve_content

# %%
improve_content({"input":data})
# Out:
# {'improved_data': {'achievements': 'Achievements: Expertise in LangGraph Development\n\n- Contributed significantly to the development of advanced natural language processing models, enhancing their accuracy and efficiency.\n- Spearheaded projects that utilized LangGraph for complex text analysis tasks, resulting in improved data insights and decision-making processes.\n- Developed innovative solutions leveraging LangGraph capabilities, leading to significant improvements in system performance and user experience.\n- Authored technical papers and presentations showcasing the cutting-edge applications of LangGraph in various domains, including but not limited to healthcare, finance, and technology.'}}

# %%
from agents.cv_builder import format_cv

# %%
format_cv({"input":data})
# Out:
# {'final_cv': {'name': 'Salar Ahmed',
#   'jobTitle': None,
#   'company': None,
#   'duration': 'None - None',
#   'achievements': None,
#   'education': {'degree': None, 'institute': None, 'duration': 'None - None'},
#   'skills': None}}
